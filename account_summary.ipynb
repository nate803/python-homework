# %% [markdown]
# # FINTECH Home Work: Budget Starter
# ## Use of PLAID API'S
# ## Student: Nate Walker
# ### Date: April 17, 2020

# %%
import os
import plaid
import requests
import datetime
import json
import pandas as pd
# %matplotlib inline

## Nate's Note to self: Use "myenv" to run code!

# %%
def pretty_print_response(response):
  print(json.dumps(response, indent=4, sort_keys=True))

# %%
### Run the Code in the Next Code Box Below[4]
#PLAID_CLIENT_ID = os.getenv('PLAID_CLIENT_ID')
#PLAID_SECRET = os.getenv('PLAID_SECRET')
#PLAID_PUBLIC_KEY = os.getenv('PLAID_PUBLIC_KEY')
#PLAID_ENV = os.getenv('PLAID_ENV', 'sandbox')
#PLAID_PRODUCTS = os.getenv('PLAID_PRODUCTS', 'transactions')

# %%
PLAID_CLIENT_ID = '5e8d2e487a7fbc0014201100'
PLAID_PUBLIC_KEY ='3d3d6c8a1da11e972f9f445d1e8f4c'
PLAID_SBX_SECRET_KEY = 'cd89f2830a20c83b42fe7aaa673830'
PLAID_ENV = os.getenv('PLAID_ENV', 'sandbox')
PLAID_PRODUCTS = os.getenv('PLAID_PRODUCTS', 'transactions')

# %% [markdown]
# # Plaid Access Token
#
# In this section, you will use the plaid-python api to generate the correct authentication tokens to access data in the free developer Sandbox. This mimics how you might connect to your own account or a customer account, but due to privacy issues, this homework will only require connecting to and analyzing the fake data from the developer sandbox that Plaid provides.
#
# Complete the following steps to generate an access token:
# 1. Create a client to connect to plaid
# 2. Use the client to generate a public token and request the following items:
# ['transactions', 'income', 'assets']
# 3. Exchange the public token for an access token
# 4. Test the access token by requesting and printing the available test accounts

# %% [markdown]
# ### 1. Create a client to connect to plaid

# %%
INSTITUTION_ID = "ins_109508"

# %%
# YOUR CODE HERE
# Create client object
client = plaid.Client(client_id=PLAID_CLIENT_ID, secret=PLAID_SBX_SECRET_KEY, public_key=PLAID_PUBLIC_KEY, environment='sandbox')

# Get institutions
client.Institutions.get(2)  # return 2 financial institutions
# Out:
# {'institutions': [{'country_codes': ['US'],
#    'credentials': [{'label': 'Username', 'name': 'username', 'type': 'text'},
#     {'label': 'Password', 'name': 'password', 'type': 'password'}],
#    'has_mfa': True,
#    'input_spec': 'fixed',
#    'institution_id': 'ins_112060',
#    'mfa': ['code', 'list', 'questions', 'selections'],
#    'mfa_code_type': 'numeric',
#    'name': '1st Bank (Broadus, MT) - Personal',
#    'oauth': False,
#    'products': ['assets',
#     'auth',
#     'balance',
#     'transactions',
#     'income',
#     'identity'],
#    'routing_numbers': []},
#   {'country_codes': ['US'],
#    'credentials': [{'label': 'Username', 'name': 'username', 'type': 'text'},
#     {'label': 'Password', 'name': 'password', 'type': 'password'}],
#    'has_mfa': True,
#    'input_spec': 'fixed',
#    'institution_id': 'ins_112062',
#    'mfa': ['code', 'list', 'questions', 'selections'],
#    'mfa_code_type': 'numeric',
#    'name': '1st Constitution Bank - Personal',
# ...

# %% [markdown]
# ### 2. Generate a public token

# %%
# YOUR CODE HERE
# Select an institution for processing  "ins_109508"
INSTITUTION_ID = "ins_109508"

# Create public token to be exchanged for institution access token
create_tkn_response = client.Sandbox.public_token.create(INSTITUTION_ID, ['transactions','income','assets'])

# Exchange public token for access token
exchange_response = client.Item.public_token.exchange(create_tkn_response['public_token'])

# Store access token as variable
access_token = exchange_response['access_token']

# %% [markdown]
# ### 3. Exchange the public token for an access token

# %%
# YOUR CODE HERE
client.Accounts.get(access_token)   # retruns the clients
# Out:
# {'accounts': [{'account_id': 'x1DZQR7LkmfeB1EMjg9VfDVZJgb7pvFnRNPGM',
#    'balances': {'available': 100,
#     'current': 110,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '0000',
#    'name': 'Plaid Checking',
#    'official_name': 'Plaid Gold Standard 0% Interest Checking',
#    'subtype': 'checking',
#    'type': 'depository'},
#   {'account_id': 'dvMAmN5e79Fr73R58MmoUPnBD5Elp7uZxGzWz',
#    'balances': {'available': 200,
#     'current': 210,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '1111',
#    'name': 'Plaid Saving',
#    'official_name': 'Plaid Silver Standard 0.1% Interest Saving',
#    'subtype': 'savings',
#    'type': 'depository'},
#   {'account_id': 'av6LmP5JNGFLR97EekBAFWnk1jZAagC7xPJW5',
#    'balances': {'available': None,
#     'current': 1000,
#     'iso_currency_code': 'USD',
#     'limit': None,
# ...

# %% [markdown]
# ### 4. Fetch Accounts

# %%
# YOUR CODE HERE - Last 30 Days
start_date = '{:%Y-%m-%d}'.format(datetime.datetime.now() + datetime.timedelta(-30))
end_date = '{:%Y-%m-%d}'.format(datetime.datetime.now())

# Get transactions for date range
transaction_response = client.Transactions.get(access_token,start_date,end_date)

# Print JSON output
print(json.dumps(transaction_response,indent=4))  # Print of last 30 days
#print(json.dumps(transaction_response['transactions'][:2],indent=4, sort_keys=True))
# Out:
# {
#     "accounts": [
#         {
#             "account_id": "x1DZQR7LkmfeB1EMjg9VfDVZJgb7pvFnRNPGM",
#             "balances": {
#                 "available": 100,
#                 "current": 110,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "0000",
#             "name": "Plaid Checking",
#             "official_name": "Plaid Gold Standard 0% Interest Checking",
#             "subtype": "checking",
#             "type": "depository"
#         },
#         {
#             "account_id": "dvMAmN5e79Fr73R58MmoUPnBD5Elp7uZxGzWz",
#             "balances": {
#                 "available": 200,
#                 "current": 210,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "1111",
#             "name": "Plaid Saving",
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Account Transactions with Plaid
#
# In this section, you will use the Plaid Python SDK to connect to the Developer Sandbox account and grab a list of transactions. You will need to complete the following steps:
#
#
# 1. Use the access token to fetch the transactions for the last 90 days
# 2. Print the categories for each transaction type
# 3. Create a new DataFrame using the following fields from the JSON transaction data: `date, name, amount, category`. (For categories with more than one label, just use the first category label in the list)
# 4. Convert the data types to the appropriate types (i.e. datetimeindex for the date and float for the amount)

# %% [markdown]
# ### 1. Fetch the Transactions for the last 90 days

# %%
# YOUR CODE HERE
start_date = '{:%Y-%m-%d}'.format(datetime.datetime.now() + datetime.timedelta(-90))  #last 90 days transactions
end_date = '{:%Y-%m-%d}'.format(datetime.datetime.now())

# Get transactions for date range
transaction_response = client.Transactions.get(access_token,start_date,end_date)

# Print JSON output
print(json.dumps(transaction_response,indent=4)) # Print of last 90 days
#print(json.dumps(transaction_response['transactions'][1],indent=4, sort_keys=True)) # first 5 rows
# Out:
# {
#     "accounts": [
#         {
#             "account_id": "x1DZQR7LkmfeB1EMjg9VfDVZJgb7pvFnRNPGM",
#             "balances": {
#                 "available": 100,
#                 "current": 110,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "0000",
#             "name": "Plaid Checking",
#             "official_name": "Plaid Gold Standard 0% Interest Checking",
#             "subtype": "checking",
#             "type": "depository"
#         },
#         {
#             "account_id": "dvMAmN5e79Fr73R58MmoUPnBD5Elp7uZxGzWz",
#             "balances": {
#                 "available": 200,
#                 "current": 210,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "1111",
#             "name": "Plaid Saving",
# ...

# %% [markdown]
# ### 2. Print the categories for each transaction

# %%
# YOUR CODE HERE
# Print JSON output by Category Name
#print(json.dumps(transaction_response['transactions'][:6],indent=4, sort_keys=True))

#transaction_response['transactions'][0]['category']       # print of the 0th category
#transaction_response['transactions']#['category']        #print of the all transactions


#transaction_response['item']['available_products']  # Note this code returns the items

#category = transaction_response['transactions'][6]['category']
#print(category)

# Iterate and parse JSON response
for transaction in transaction_response['transactions']:
    #if transaction['date'] == '2020-04-15':
    print(json.dumps(transaction['category'], indent=4, sort_keys=True))
# Out:
# [
#     "Payment",
#     "Credit Card"
# ]
# [
#     "Travel",
#     "Taxi"
# ]
# [
#     "Transfer",
#     "Debit"
# ]
# [
#     "Transfer",
#     "Deposit"
# ]
# [
#     "Recreation",
#     "Gyms and Fitness Centers"
# ]
# [
#     "Travel",
#     "Airlines and Aviation Services"
# ]
# [
#     "Food and Drink",
#     "Restaurants",
#     "Fast Food"
# ]
# [
#     "Food and Drink",
#     "Restaurants",
#     "Coffee Shop"
# ]
# [
#     "Food and Drink",
#     "Restaurants"
# ]
# [
#     "Transfer",
#     "Credit"
# ]
# [
#     "Travel",
#     "Airlines and Aviation Services"
# ]
# [
#     "Travel",
#     "Taxi"
# ]
# [
#     "Food and Drink",
#     "Restaurants"
# ]
# [
#     "Payment"
# ]
# [
#     "Food and Drink",
#     "Restaurants",
#     "Fast Food"
# ]
# [
#     "Shops",
#     "Sporting Goods"
# ]
# [
#     "Payment",
#     "Credit Card"
# ]
# [
#     "Travel",
#     "Taxi"
# ]
# [
#     "Transfer",
#     "Debit"
# ]
# [
#     "Transfer",
#     "Deposit"
# ]
# [
# ...

# %% [markdown]
# ### 3. Create a new DataFrame using the following fields from the JSON transaction data: date, name, amount, category.
#
# (For categories with more than one label, just use the first category label in the list)

# %%
# YOUR CODE HERE
# Create a new empty DataFrame - Nate's Code

for transaction in transaction_response['transactions']:
    categories = []
    dates = []
    poi = []
    amount = []
    categories.append(transaction['category']) 
    categories = transaction['category'][0]
    dates.append(transaction['date'])
    poi.append(transaction['name'])
    amount.append(transaction['amount'])
    
for i in range(len(dates)):
    print(f"{dates[i]} {poi[i]} \t ${amount[i]} cat:{categories[i]}")
    
new_df = pd.DataFrame(list(zip(dates,poi,amount,categories)),
             columns = ['Date', 'Transaction','Amount','Category'])
new_df.head()           # Prints only one row
#new_df.tail()
# Out:
# 2020-01-25 Madison Bicycle Shop 	 $500 cat:S
#          Date           Transaction  Amount Category
# 0  2020-01-25  Madison Bicycle Shop     500        S

# %%
# YOUR CODE HERE
# Create a new empty DataFrame
#transaction_df = pd.DataFrame()
#transaction_df['transactions','date','name','amount'] =pd.DataFrame([transaction_response.date,name,amount for transaction in transactions]) 

transaction = transaction_response['transactions']  #new transaction variable
#transaction                                        # list of the transaction variable

for transact in transaction:
    categories = []
    dates = []
    poi = []
    amount = []
    categories.append(transact['category']) 
    categories = transact['category'][0]
    dates.append(transact['date'])
    poi.append(transact['name'])
    amount.append(transact['amount'])
    
for i in range(len(dates)):
    print(f"{dates[i]} {poi[i]} \t ${amount[i]} cat:{categories[i]}")
    
df = pd.DataFrame(list(zip(dates,poi,amount,categories)),
             columns = ['Date', 'Transaction','Amount','Category'])

df.head()
# Out:
# 2020-03-25 Madison Bicycle Shop 	 $500 cat:S
#          Date           Transaction  Amount Category
# 0  2020-03-25  Madison Bicycle Shop     500        S

# %% [markdown]
# ### 4. Convert the data types to the appropriate types
#
# (i.e. datetimeindex for the date and float for the amount)

# %%
# YOUR CODE HERE
new_df.index = new_df.index.Date
new_df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-3eae911cd20d> in <module>
#       1 # YOUR CODE HERE
# ----> 2 new_df.index = new_df.index.Date
#       3 new_df.head()
#
# AttributeError: 'RangeIndex' object has no attribute 'Date'

# %% [markdown]
# ---

# %% [markdown]
# # Income Analysis with Plaid
#
# In this section, you will use the Plaid Sandbox to complete the following:
# 1. Determine the previous year's gross income and print the results
# 2. Determine the current monthly income and print the results
# 3. Determine the projected yearly income and print the results

# %% [markdown]
# ---

# %% [markdown]
# # Budget Analysis
# In this section, you will use the transactions DataFrame to analyze the customer's budget
#
# 1. Calculate the total spending per category and print the results (Hint: groupby or count transactions per category)
# 2. Generate a bar chart with the number of transactions for each category
# 3. Calculate the expenses per month
# 4. Plot the total expenses per month

# %% [markdown]
# ### Calculate the expenses per category

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Calculate the expenses per month

# %%
# YOUR CODE HERE
